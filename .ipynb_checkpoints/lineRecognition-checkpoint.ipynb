# %%
# pip3 install opencv-python numpy matplotlib
import cv2 as cv

import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import os
from scipy.signal import find_peaks
direc= os.getcwd()

# %%
# Create necessary dirs if they do not exist
direc= os.getcwd()
dirs = [direc+ "/linesdetected", direc+ "/output", direc+ "/cropped"]

for path in dirs:
    isExist = os.path.exists(path)

    if not isExist:
  
      # Create a new directory because it does not exist 
      os.makedirs(path)
      print("The new directory -{0} \n is created!".format(path))

# %%
# algorithm using histogram projection

# %%
import numpy as np
import cv2 as cv
def fixLineBeginningAndEnds(inputImage, orig):
    
    BlackFrame = np.zeros(inputImage.shape, np.uint8)
    contours, _ = cv.findContours(
        inputImage, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    for contour in contours:
        x, y, w, h = cv.boundingRect(contour) 
        if (h <=3):
            continue
        cropped = inputImage[y:y + h, x:x + w]
        orig1 =cv.bitwise_not(orig[y:y + h, x:x + w].copy())
        space = np.linspace(1, w, 15)
        average = sum(np.sum(orig1,axis=1)/15)
        start = 0
        stop = 0
        for count,k in enumerate(space):
            val = sum(np.sum(orig1[:,:int(k)],axis=1))
            if(val <average/3):
                start = start+1
            if(val < (14.5 * average)):
                stop = stop+1
        cv.rectangle(BlackFrame,(x + int(start* w/15),y),(x+w-int(w*(15-stop)/15),y+h),(255, 255, 255),-1)
    return BlackFrame

# %%
from skimage.io import imread
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
from skimage.filters import sobel
import numpy as np
from PIL import Image
import glob
import os
import cv2 as cv
import cv2
def horizontal_projections(img):
    return np.sum(img, axis=1)

def calculateXProjection(array):
    return np.sum(array,axis=0).tolist()

def find_peak_regions(hpp, divider=2.5):
    threshold = (np.max(hpp)-np.min(hpp))/divider
    peaks = []
    peaks_index = []
    for i, hppv in enumerate(hpp):
        if hppv < threshold:
            peaks.append([i, hppv])
    return peaks

def main():
    direc= os.getcwd()



#Binarize all files in images
    #applyBinarizationAndSave()
    for img in glob.glob(direc + '/images' + '/*.jpg'):
        try:
            print(img)
            image = cv.imread(img)
            image = cv.cvtColor(image, cv2.COLOR_BGR2GRAY)
            th, image = cv.threshold(image, 150, 255, cv.THRESH_BINARY)
            rightLeftEdge= int(600/5)
            rightRightEdge=int(770/5)
            sobel_image = sobel(image)
            hpp = calculateXProjection(sobel_image)
    #print(type(hpp))
    #print(hpp)
            temp = [sum(hpp[i:i+5]) for i in range(0, len(hpp), 5)]


            leftParagraphCornerIndex = int(temp.index(min(temp[40:60]))*5)
            RightParagraphCornerIndex = int(temp.index(min(temp[rightLeftEdge:rightRightEdge]))*5)

            sobel_image_left = sobel(image[:, :(leftParagraphCornerIndex)])
            sobel_image_middle = sobel(image[:, leftParagraphCornerIndex:RightParagraphCornerIndex])
            sobel_image_right = sobel(image[:, RightParagraphCornerIndex:])

            imag = [sobel_image_left, sobel_image_middle, sobel_image_right]

            new_image=[]
            for i in range(3):
                hpp = horizontal_projections(imag[i])
                peaks = find_peak_regions(hpp)
                if(len(peaks) == 0):
                    new_image.append(np.zeros(imag[i].shape, np.uint8))
                    continue
                    
                peaks_index = np.array(peaks)[:,0].astype(int)

                segmented_img = np.ones(imag[i].shape, np.uint8)

                r,c = segmented_img.shape
                for ri in range(r):
                    if ri in peaks_index:
                        segmented_img[ri, :] = 0
                
                new_image.append(segmented_img)
    
            sections_of_image=[]
            for k in new_image:
                height, width, *rest= k.shape
                for i in range(height):
                    for j in range(width):
                        if(j<5):
                            if (k[i, j] ==1):
                                k[i, j] =0
                sections_of_image.append(k)

            predictions = np.concatenate((sections_of_image[0], sections_of_image[1], sections_of_image[2]), axis=1)
            
            
            
            predictions[predictions == 1] = 255
            output = fixLineBeginningAndEnds(predictions,image)
            im = Image.fromarray(output)
            
            im.save("output/" + img[img.find("images")+7:-4] + ".png")
            
        except Exception as e:
            print(e)

if __name__ == "__main__":
    main()
# Out:
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-018r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-018v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-019r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-019v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-020r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-021r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-021v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-022r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-022v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-023r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-023v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-024r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-024v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-025r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-025v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-026r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-026v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-027r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-027v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-028r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-028v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-029r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-029v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-030r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-030v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-031r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-031v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-032r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-032v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-033r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-033v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-034r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-034v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-035r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-035v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-036r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-036v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-037r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-037v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-038r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-038v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-039r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-039v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-040r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-040v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-041r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-041v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-042r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-042v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-043r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-043v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-044r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-044v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-045r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-045v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-046r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-046v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-047r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-047v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-048r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-048v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-049r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-049v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-050r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-050v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-051r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-051v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-052r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-052v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-053r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-053v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-054r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-054v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-055r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-055v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-056r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-056v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-057r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-057v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-058r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-058v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-059r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-059v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-060r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-060v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-061r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-061v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-062r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-062v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-063r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-063v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-064r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-064v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-065r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-065v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-066r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-066v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-067r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-067v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-068r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-068v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-069r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-069v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-070r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-070v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-071r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-071v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-072r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-072v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-073r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-073v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-074r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-074v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-075r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-075v.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-076r.jpg
# C:\Users\datog\Downloads\for-upload\DIA-Project/images\fmb-cb-55-076v.jpg

# %%
#Naive Hought Transform

# %%
import cv2
import numpy as np
import cv2
import numpy as np
from math import atan2
import os
import glob
from PIL import Image
# pip3 install opencv-python numpy matplotlib
import cv2 as cv

import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import os
from scipy.signal import find_peaks
direc= os.getcwd()
direc= os.getcwd()
i =0
for img in glob.glob(direc + '/images' + '/*.jpg'):
    image = cv2.imread(img)
#cv2.imshow('orig',image)
#cv2.waitKey(0)

#grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    #cv2.imshow('binary',gray)
    cv2.waitKey(0)
    
    blurred_image = cv2.GaussianBlur(gray, (9, 9), 0)
    cv2.imshow('blurred',blurred_image)
#binary
    ret,thresh = cv2.threshold(blurred_image,150,255,cv2.THRESH_BINARY_INV)
    cv2.imshow('binary',thresh)
    cv2.waitKey(0)

#dilation
    kernel = np.ones((3,10), np.uint8)
    img_dilation = cv2.dilate(thresh, kernel, iterations=1)
    #cv2.imshow('dilated',img_dilation)

    kernel = np.ones((8,20), np.uint8)
    img_erosion = cv2.erode(img_dilation, kernel, iterations=1)
    cv2.imshow('second',img_erosion)
    
    kernel = np.ones((1,30), np.uint8)  # note this is a horizontal kernel
    img_dilation = cv2.dilate(img_erosion, kernel, iterations=1)
    kernel = np.ones((3,10), np.uint8)
    img_erosion = cv2.erode(img_dilation, kernel, iterations=1)
    cv2.imshow('second',img_dilation)

#im = Image.fromarray(img_erosion)
#im.save("your_file.jpeg")

    BlackFrame = np.zeros(image.shape, np.uint8)

#gray = cv2.cvtColor(e_im, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(img_dilation, 75, 150)
    cv2.imshow('second',edges)
    lines = cv2.HoughLinesP(edges, 1, np.pi/90, 30, minLineLength = 40, maxLineGap=50)
    for line in lines:
        x1, y1, x2, y2 = line[0]
    
        if(x1!=x2 and (abs((y1-y2)/(x1-x2)) < np.pi/90)):
            cv2.line(BlackFrame, (x1, y1), (x2, y2), (255,255,255), 8)
    im = Image.fromarray(BlackFrame)
    im.save("output/" + img[img.find("images")+7:])
    i=i+1
#cv2.imshow("linesEdges", edges)
#cv2.imshow("linesDetected", BlackFrame)
cv2.waitKey(0)
cv2.destroyAllWindows()
